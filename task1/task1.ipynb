# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('social_media_sleep_stress_productivity_11000.csv')
df.head()
# Out:
#    user_id  age  daily_screen_time_hours  social_media_hours  sleep_hours  \
# 0        1   44                     2.39                1.93         8.46
# 1        2   30                     7.22                5.24         7.34
# 2        3   23                     2.56                4.64         4.69
# 3        4   36                     8.75                4.89         5.05
# 4        5   34                    10.96                2.77         7.12
#
#    exercise_minutes  study_work_hours  productivity_score stress_level  \
# 0                61              3.73               33.86          Low
# 1                28              6.80               85.32          Low
# 2                 8              4.47               60.07         High
# 3                53              9.53               36.46       Medium
# 4                83              7.01               32.93       Medium
#
#     platform
# 0    YouTube
# 1    YouTube
# 2    YouTube
# 3   LinkedIn
# 4  Instagram

# %%
df.tail()
# Out:
#        user_id  age  daily_screen_time_hours  social_media_hours  sleep_hours  \
# 10995    10996   27                     8.25                7.69         6.40
# 10996    10997   35                     8.55                6.88         6.43
# 10997    10998   38                     1.25                6.66         7.21
# 10998    10999   45                     1.59                4.02         3.50
# 10999    11000   45                     6.86                2.09         7.48
#
#        exercise_minutes  study_work_hours  productivity_score stress_level  \
# 10995                82              2.08               23.52          Low
# 10996                62              6.67               48.11         High
# 10997               104              7.72               14.62          Low
# 10998               106              8.86               39.40          Low
# 10999                33              6.24               38.82       Medium
#
#         platform
# 10995   LinkedIn
# ...

# %%
df['age'].value_counts()
# Out:
# age
# 41    371
# 28    370
# 32    367
# 38    354
# 43    344
# 31    343
# 44    338
# 37    333
# 33    332
# 39    331
# 36    330
# 34    330
# 23    329
# 17    328
# 48    328
# 27    326
# 30    325
# 40    323
# 19    321
# 18    318
# 21    317
# 47    317
# 29    313
# 35    312
# 24    311
# 25    309
# 16    304
# 20    303
# 45    302
# 26    301
# 49    301
# 22    294
# 46    288
# 42    287
# Name: count, dtype: int64

# %%
df['age'].unique()
# Out:
# array([44, 30, 23, 36, 34, 38, 26, 39, 18, 37, 17, 45, 48, 27, 40, 42, 43,
#        31, 22, 24, 33, 19, 29, 41, 35, 32, 21, 49, 25, 46, 16, 20, 28, 47])

# %%
df['age'].value_counts()
# Out:
# age
# 41    371
# 28    370
# 32    367
# 38    354
# 43    344
# 31    343
# 44    338
# 37    333
# 33    332
# 39    331
# 36    330
# 34    330
# 23    329
# 17    328
# 48    328
# 27    326
# 30    325
# 40    323
# 19    321
# 18    318
# 21    317
# 47    317
# 29    313
# 35    312
# 24    311
# 25    309
# 16    304
# 20    303
# 45    302
# 26    301
# 49    301
# 22    294
# 46    288
# 42    287
# Name: count, dtype: int64

# %%
df[df['age'] == '41']
# Out:
# Empty DataFrame
# Columns: [user_id, age, daily_screen_time_hours, social_media_hours, sleep_hours, exercise_minutes, study_work_hours, productivity_score, stress_level, platform]
# Index: []

# %%
df.head()
# Out:
#    user_id  age  daily_screen_time_hours  social_media_hours  sleep_hours  \
# 0        1   44                     2.39                1.93         8.46
# 1        2   30                     7.22                5.24         7.34
# 2        3   23                     2.56                4.64         4.69
# 3        4   36                     8.75                4.89         5.05
# 4        5   34                    10.96                2.77         7.12
#
#    exercise_minutes  study_work_hours  productivity_score stress_level  \
# 0                61              3.73               33.86          Low
# 1                28              6.80               85.32          Low
# 2                 8              4.47               60.07         High
# 3                53              9.53               36.46       Medium
# 4                83              7.01               32.93       Medium
#
#     platform
# 0    YouTube
# 1    YouTube
# 2    YouTube
# 3   LinkedIn
# 4  Instagram

# %%
df['stress_level'].value_counts()
# Out:
# stress_level
# Low       3715
# Medium    3681
# High      3604
# Name: count, dtype: int64

# %%
df['platform'].value_counts()
# Out:
# platform
# LinkedIn     2239
# Snapchat     2235
# YouTube      2200
# Twitter      2183
# Instagram    2143
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# user_id                    0
# age                        0
# daily_screen_time_hours    0
# social_media_hours         0
# sleep_hours                0
# exercise_minutes           0
# study_work_hours           0
# productivity_score         0
# stress_level               0
# platform                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10995    False
# 10996    False
# 10997    False
# 10998    False
# 10999    False
# Length: 11000, dtype: bool

# %%
df.dtypes
# Out:
# user_id                      int64
# age                          int64
# daily_screen_time_hours    float64
# social_media_hours         float64
# sleep_hours                float64
# exercise_minutes             int64
# study_work_hours           float64
# productivity_score         float64
# stress_level                   str
# platform                       str
# dtype: object

# %% [markdown]
# Change datatypes

# %%
df['user_id']=df['user_id'].astype('int32')
df['age']=df['age'].astype('int32')
df['daily_screen_time_hours']=df['daily_screen_time_hours'].astype('float32')
df['social_media_hours']=df['social_media_hours'].astype('float32')
df['sleep_hours']=df['sleep_hours'].astype('float32')
df['exercise_minutes']=df['exercise_minutes'].astype('int32')
df['study_work_hours']=df['study_work_hours'].astype('float32')
df['productivity_score']=df['productivity_score'].astype('float32')

# %%
df.dtypes
# Out:
# user_id                      int32
# age                          int32
# daily_screen_time_hours    float32
# social_media_hours         float32
# sleep_hours                float32
# exercise_minutes             int32
# study_work_hours           float32
# productivity_score         float32
# stress_level                   str
# platform                       str
# dtype: object

# %%
df['age'].value_counts().head(10)
# Out:
# age
# 41    371
# 28    370
# 32    367
# 38    354
# 43    344
# 31    343
# 44    338
# 37    333
# 33    332
# 39    331
# Name: count, dtype: int64

# %%
# print(df[df['age'].isin(['41', '28','32','38','43','31','44','37','33','39'])])
age = df[df['age'].isin([41, 28, 32, 38, 43, 31, 44, 37, 33, 39])]

# %%
sns.countplot(data= age, x='age')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
df['stress_level'].value_counts().head()
# Out:
# stress_level
# Low       3715
# Medium    3681
# High      3604
# Name: count, dtype: int64

# %%
age = df[df['stress_level'].isin(['low', 'Medium', 'High'])]
